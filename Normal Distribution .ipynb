# %% [markdown]
# # Normal Distribution

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
import math
mean, std = 20, 2
cdf = lambda x: 0.5 * (1 + math.erf((x - mean) / (std * (2 ** 0.5))))

# Less than 19.5
print('{:.3f}'.format(cdf(19.5)))
# Between 20 and 22
print('{:.3f}'.format(cdf(22) - cdf(20)))
# Out:
# 0.401
# 0.341

# %%
from scipy.stats import norm
mean, std = 20, 2
norm_dist = norm(mean, std)
print(round(norm_dist.cdf(19.5), 3))
print(round((norm_dist.cdf(22) - norm_dist.cdf(20)), 3))
# Out:
# 0.401
# 0.341

# %% [markdown]
# # EVERYTHING FROM SCRATCH!!!

# %%
mu, sigma = 20, 2

# ____ with scipy ____ #
# from scipy.stats import norm
# print(round(norm.cdf(19.5, mu, sigma), 3))
# print(round(norm.cdf(22, mu, sigma) - norm.cdf(20, mu, sigma), 3))


# ____ by numerical integration ____ #

def normal_pdf(x, mu, sigma):
    e = 2.718281
    pi = 3.1415926
    error = (x - mu)**2
    var = sigma**2
    nom = e**(-error/(2*var))
    denom = sigma*(2*pi)**0.5
    return nom/denom

def integrate_normal(a,b,n,mu,sigma):
    dx = float(b-a)/n
    area = 0
    midpoint = a + (dx/2)
    for i in range(n):
        area += normal_pdf(midpoint, mu, sigma) * dx
        midpoint += dx
    return area

n = 100
print(round(integrate_normal(0, 19.5, n, mu, sigma), 3))
print(round(integrate_normal(20, 22, n, mu, sigma), 3))
# Out:
# 0.401
# 0.341

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
import math
mean, std = 70, 10
cdf = lambda x: 0.5 * (1 + math.erf((x - mean) / (std * (2 ** 0.5))))


print(round((1-cdf(80))*100,2))
print(round((1-cdf(60))*100,2))
print(round((cdf(60))*100,2))
# Out:
# 15.87
# 84.13
# 15.87

# %%
mu = 70
sigma = 10
n = 100
print(round(integrate_normal(80, 100, n, mu, sigma), 3))
print(round(integrate_normal(60, 100, n, mu, sigma), 3))
print(round(integrate_normal(0, 60, n, mu, sigma), 3))
# Out:
# 0.157
# 0.84
# 0.159
