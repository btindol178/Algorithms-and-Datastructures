# %% [markdown]
# # Poisson Distribution

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# Task <BR>
# A random variable,X , follows Poisson distribution with mean of 2.5. Find the probability with which the random variable X is equal to 5.

# %%
from math import factorial, exp

u = 2.5
e = 2.71828 # euler's number constant
x = 5

#(e**-u)*(u**x)/x
poisson = (((u)**x)*(e)**-(u))/factorial(x)
poisson
# Out:
# 0.06680105522522659

# %%
import math 
def poi(k,Lambda):
    return (Lambda**k *(math.e)**(-Lambda))/(math.factorial(k))

Lambda=float(input())
k=int(input())
print("%.3f"%(poi(k,Lambda)))

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
# Input from stdin
#averageX, averageY = [float(num) for num in input().split(" ")]
averageX = .88
averageY = 1.55
# Cost
CostX = 160 + 40*(averageX + averageX**2)
CostY = 128 + 40*(averageY + averageY**2)

print(round(CostX, 3))
print(round(CostY, 3))
#Explanation:
#One doesn't need to actually calculate the Poisson distribution (and for that matter, we do not know  anyway). What one should do is realise that for some random Poisson variable, , the expectation value and the variance ar
# Out:
# 226.176
# 286.1
