# %% [markdown]
# # Compound Event Probability

# %% [markdown]
# There are 3 urns labeled X, Y and Z
#
# - Urn X contains 4 red balls and 3 black balls
# - Urn Y contains 5 red balls and 4 black balls
# - Urn Z contains 4 red balls adn 4 black balls
#
# One balls is drawn from each of the urns.
# What is the probability that of the 3 balls drawn 2 are red and 1 is black?

# %%
# itertools has a product cartesian which finds ever combination of options
import itertools
from fractions import Fraction

X = ["b","b","b","r","r","r","r"]
Y = ["b","b","b","b","r","r","r","r","r"]
Z = ["b","b","b","b","r","r","r","r"]

r = [(i)for i in itertools.product(X,Y,Z)]
e = list(map(lambda x : x.count('r') == 2 and x.count('b') == 1,r))
Fraction(e.count(True),len(e))
# Out:
# Fraction(17, 42)

# %%
#he gets the Cartesian product of X, Y and Z as a list of tuples, 
#effectively listing each possible combination of balls drawn. 
#Then he counts all the tuples where there's 2 red and 1 black ball and calculates the fraction 
#of those occuring 
#in the total number of combinations.

# %%
r = [(i)for i in itertools.product(X,Y,Z)]
r
# Out:
# [('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'b'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'b', 'r'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'r'),
#  ('b', 'r', 'b'),
#  ('b', 'r', 'b'),
# ...

# %%
# Lets break this down
e = list(map(lambda x : x.count('r') == 2 and x.count('b') == 1,r))

e
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
