# %% [markdown]
# # Least Square Regression Line

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
# in r
# x = c(1, 2, 3, 4, 5)
# y = c(2, 1, 4, 3, 5)

# m = lm(y ~ x)
# summary(m)

# in python 
# from sklearn import linear_model
# import numpy as np
# xl = [1, 2, 3, 4, 5]
# x = np.asarray(xl).reshape(-1, 1)
# y = [2, 1, 4, 3, 5]
# lm = linear_model.LinearRegression()
# lm.fit(x, y)
# print(lm.intercept_)
# print(lm.coef_[0])

# %%
# in R 
# data <- read.table("stdin",header=F, skip=0)
# dat <- t(data)
# x=dat[1,];
# y=dat[2,];
# model = lm(y~x)
# cat(round(predict(model, newdata=data.frame(x=80),se.fit=T)[[1]],digits=3))

# %%
n = 5
xy = [map(int, input().split()) for _ in range(n)]
sx, sy, sx2, sxy = map(sum, zip(*[(x, y, x**2, x * y) for x, y in xy]))
b = (n * sxy - sx * sy) / (n * sx2 - sx**2)
a = (sy / n) - b * (sx / n)
print('{:.3f}'.format(a + b * 80))

# %%
# x = [95,85,80,70,60]
# y = [85,95,70,65,70]
x, y = [], []
for _ in range(5):
    i = input().split()
    x.append(int(i[0]))
    y.append(int(i[1]))
n = len(x)
x_sum = sum(x)
x_sum_sqr = x_sum**2
x_sqr_sum = sum([x_i**2 for x_i in x])
y_sum = sum(y)
sum_prod_xy = 0
for x_i,y_i in zip(x,y):
    sum_prod_xy += (x_i*y_i)
b = (n*sum_prod_xy - x_sum*y_sum) / (n*x_sqr_sum - x_sum_sqr)
y_mean = y_sum/n
x_mean = x_sum/n
a = y_mean - b*x_mean

# to make prediction
x_test = 80
y_test = a + b * x_test
print("%.3f" %y_test)   # 78.288

# %%
# x = [95,85,80,70,60]
# y = [85,95,70,65,70]
from statistics import mean, pstdev

def pearson(x, y):
    n = len(x)
    mx, sx, my, sy = mean(x), pstdev(x), mean(y), pstdev(y)
    return sum((xi - mx) * (yi - my) for xi, yi in zip(x, y)) / (n * sx * sy)

def linear_regression(x, y):
    b = pearson(x, y) * pstdev(y) / pstdev(x)
    return mean(y) - b * mean(x), b

x, y = [], []
for _ in range(5):
    i = input().split()
    x.append(int(i[0]))
    y.append(int(i[1]))
a, b = linear_regression(x, y)

# to make prediction
x_test = 80
y_test = a + b * x_test
print("%.3f" %y_test)   # 78.288

# %%
from statistics import mean, pstdev


def pearson(x, y):
    mx, sx, my, sy = mean(x), pstdev(x), mean(y), pstdev(y)
    return sum((xi - mx) * (yi - my) for xi, yi in zip(x, y)) / (len(x) * sx * sy)


def linear_regression(x, y):
    b = pearson(x, y) * pstdev(y) / pstdev(x)
    return mean(y) - b * mean(x), b


x, y = zip(*(map(float, input().split()) for _ in range(5)))
a, b = linear_regression(x, y)
print(f'{a+b*80:.3f}')

# %%
x1, y1 = input().split()
x2, y2 = input().split()
x3, y3 = input().split()
x4, y4 = input().split()
x5, y5 = input().split()
x1, y1, x2, y2, x3, y3, x4, y4, x5, y5 = int(x1), int(y1), int(x2), int(y2), int(x3), int(y3), int(x4), int(y4), int(x5), int(y5)
X = [x1, x2,x3,x4,x5]
Y = [y1,y2,y3,y4,y5]
sum1 = [X[i]*Y[i] for i in range(len(X))]
a = len(X)*sum(sum1)
sum2 = [X[i] for i in range(len(X))]
sum3 = [Y[i] for i in range(len(X))]
b = sum(sum2)*sum(sum3)
sum4 = [X[i]*X[i] for i in range(len(X))]
c = len(X)*sum(sum4)
sum5 = [X[i] for i in range(len(X))]
d = (sum(sum5))**2
Numerator = a - b
Denominator = c - d
B = Numerator/Denominator
meanX = sum(X)/len(X)
meanY = sum(Y)/len(Y)
A = meanY - B*meanX
print(round(A + B*80, 3))
# Out:
# 39 47
# 28 48
# 58 39
# 39 68
# 38 69
# 34.5
